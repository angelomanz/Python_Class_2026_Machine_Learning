# %% [markdown]
# <a href="https://colab.research.google.com/github/angelomanz/Python_Class_2026_Machine_Learning/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10,25,30,15,40]
total = 0

for num in numbers :
  total +=num
print(f'Total: {total}')
# Out:
# Total: 120
